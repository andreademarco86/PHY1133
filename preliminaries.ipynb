# %% [markdown]
# # Preliminaries
#
# In this course we will be using the Python programming language. Python is a general-purpose language which, with libraries such as NumPy, SciPy, and Matplotlib, provides a powerful environment for scientific computing.

# %% [markdown]
# # Course overview
#
# The following lists the overview for this course:
#
# - 4 ECTS Credits
# - 100% Assignment
# - 2hr lab sessions
# - Course material will be provided
# - For labs there is no need to buy any books, as there are plenty of resources online
# - You are encouraged to bring your laptop and work on the course material in class
#
# If you have any questions you can contact me on andrea.demarco@um.edu.mt. You can also come to my office with any questions: Room 226, Maths and Physics building. It is advised to send an email to book a slot to make sure that I will be available.

# %% [markdown]
# ## BONUS / SELF-STUDY

# %% [markdown]
# ## Why bother to learn programming?
#
# Programming is becoming a necessity in most of the sciences. We'll stick to physical problems in this course. Traditional analytical tools have certain limitations, since although they have enabled us to solve an incredible range of problems, they are mostly restricted to linear systems. And the vast majority of outstanding problems are inherently non-linear.
#
# Also, spurred by the rising cost of experimentation, computational physics is used to conduct "experiments" in the virtual world through simulations. Modern experiments and instruments also tend to generate a lot of data which cannot be processed by hand, so software is required to aid the scientist.
#
# Computational physics serves as a critical role at the interface between experimental and theoretical physics.

# %% [markdown]
# ## What is a computer?
#
# A computer is a programmable machine that, under the control of a stored program, accepts and processes data to produce information.
#
# Other definitions and the extended computer-systems discussion are retained below for reference.

# %% [markdown]
# ## Some definitions
#
# - Computers carry out instructions, a set of which is called a **program**.
# - A program is written using a **programming language**.
# - **Software** describes programs and data; **hardware** describes the devices making up a computer.
# - **Code** is the textual representation of a program.
# - A **compiler** transforms code into a form the CPU can execute.
# - An **interpreter** transforms code as it is executed.
# - A **bug** is incorrect program behaviour; **debugging** is the process of fixing it.
#
# For a high-level introduction of how computers work, have a look at [these slides](introduction_computer_systems.pptx).

# %% [markdown]
# ## Course access and tools

# %% [markdown]
# ## Course Notes
#
# A [link](https://mybinder.org/v2/gh/andreademarco86/phy1133/main?urlpath=tree/index.ipynb) to these course notes will be provided on VLE. Note that there are plenty of other notebooks available for viewing here, so feel free to have a look around.
#
# ## Online Python Interpreter
#
# Primarily we'll be using the online Python interpreter [Colab](https://colab.research.google.com).
#
# ***
# Back to [index](index.ipynb) page
